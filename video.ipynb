# %%
# !nvidia-smi
# Out:
# Wed Dec  6 10:14:03 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.4/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LjLWAG4N5OeI5exgSdEo")
project = rf.workspace("project-sawkw").project("emergency-vehicle-detection-el8ej")
dataset = project.version(4).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Emergency-Vehicle-Detection-4 in yolov8:: 100%|██████████| 7232/7232 [00:01<00:00, 4823.86it/s]

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data="/content/Emergency-Vehicle-Detection-4/data.yaml" epochs=50 imgsz=800 plots=True
# Out:
# /content
# New https://pypi.org/project/ultralytics/8.0.222 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
 # !yolo task=detect mode=predict model=best.pt conf=0.25 source="VIDEO-2023-12-07-23-56-18.mp4" stream_buffer=True save_txt=True
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.11.5 torch-2.1.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (1/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 140.8ms
# video 1/1 (2/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 123.5ms
# video 1/1 (3/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 (no detections), 119.7ms
# video 1/1 (4/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 121.2ms
# video 1/1 (5/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 119.9ms
# video 1/1 (6/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 117.1ms
# video 1/1 (7/289) /Users/faheemv/Desktop/IoT project/VIDEO-2023-12-07-23-56-18.mp4: 480x800 1 not_emergency, 116.5ms
# ...

# %%
print(type(result))
# Out:
# <class 'IPython.utils.text.SList'>
